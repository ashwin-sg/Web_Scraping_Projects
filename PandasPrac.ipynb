# %%
import pandas as pd
import numpy as np

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.DataFrame()

# %%
df['age'] = np.random.randint(21,60,1500)
df['salary'] = np.random.randint(10000,60000,1500)
df['city'] = np.random.choice(['Mumbai','Noida','Banglore','Hyderabad','Chennai'],1500,p=[0.2, 0.2, 0.3, 0.2,0.1])
df['attrition'] = np.random.choice(['Yes','No'],1500,p=[0.3,0.7])

# %%
np.random.choice(['21,60,1500','sdsds'],1500)
# Out:
# array(['21,60,1500', 'sdsds', 'sdsds', ..., '21,60,1500', 'sdsds',
#        '21,60,1500'], dtype='<U10')

# %%
np.random.choice(['Mumbai','Noida','Banglore','Hyderabad','Chennai'],1500,p=[0.2, 0.2, 0.3, 0.2,0.1])
# Out:
# array(['Chennai', 'Banglore', 'Banglore', ..., 'Banglore', 'Banglore',
#        'Hyderabad'], dtype='<U9')

# %%
df.head()
# Out:
#    age  salary       city attrition
# 0   44   10293  Hyderabad        No
# 1   47   13175    Chennai        No
# 2   50   49527   Banglore        No
# 3   41   27640      Noida       Yes
# 4   52   37688     Mumbai       Yes

# %%
df.style.format({'salary':'${:,.0f}','age':'{:.001%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_cf406">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf406_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_cf406_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_cf406_level0_col2" class="col_heading level0 col2" >city</th>
#       <th id="T_cf406_level0_col3" class="col_heading level0 col3" >attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf406_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf406_row0_col0" class="data row0 col0" >4400.0%</td>
#       <td id="T_cf406_row0_col1" class="data row0 col1" >$10,293</td>
#       <td id="T_cf406_row0_col2" class="data row0 col2" >Hyderabad</td>
#       <td id="T_cf406_row0_col3" class="data row0 col3" >No</td>
#     </tr>
#     <tr>
#       <th id="T_cf406_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
df.style.format({'salary':'${:,.0f}','age':'{:0>3d}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_318a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_318a7_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_318a7_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_318a7_level0_col2" class="col_heading level0 col2" >city</th>
#       <th id="T_318a7_level0_col3" class="col_heading level0 col3" >attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_318a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_318a7_row0_col0" class="data row0 col0" >044</td>
#       <td id="T_318a7_row0_col1" class="data row0 col1" >$10,293</td>
#       <td id="T_318a7_row0_col2" class="data row0 col2" >Hyderabad</td>
#       <td id="T_318a7_row0_col3" class="data row0 col3" >No</td>
#     </tr>
#     <tr>
#       <th id="T_318a7_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
df.head(10).style.highlight_max()
# Out:
# <style type="text/css">
# #T_a911b_row3_col2, #T_a911b_row3_col3, #T_a911b_row4_col3, #T_a911b_row5_col3, #T_a911b_row7_col2, #T_a911b_row8_col0, #T_a911b_row8_col3, #T_a911b_row9_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a911b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a911b_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_a911b_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_a911b_level0_col2" class="col_heading level0 col2" >city</th>
#       <th id="T_a911b_level0_col3" class="col_heading level0 col3" >attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a911b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a911b_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_a911b_row0_col1" class="data row0 col1" >10293</td>
#       <td id="T_a911b_row0_col2" class="data row0 col2" >Hyderabad</td>
# ...

# %%
df.head(10).style.highlight_min()
# Out:
# <style type="text/css">
# #T_0ca27_row0_col1, #T_0ca27_row0_col3, #T_0ca27_row1_col3, #T_0ca27_row2_col2, #T_0ca27_row2_col3, #T_0ca27_row5_col2, #T_0ca27_row6_col0, #T_0ca27_row6_col3, #T_0ca27_row7_col3, #T_0ca27_row9_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0ca27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ca27_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_0ca27_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_0ca27_level0_col2" class="col_heading level0 col2" >city</th>
#       <th id="T_0ca27_level0_col3" class="col_heading level0 col3" >attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ca27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ca27_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_0ca27_row0_col1" class="data row0 col1" >10293</td>
# ...

# %%
df.head(10).style.highlight_min(subset=['salary','age'],color='lightgreen')
# Out:
# <style type="text/css">
# #T_4f358_row0_col1, #T_4f358_row6_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4f358">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f358_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_4f358_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_4f358_level0_col2" class="col_heading level0 col2" >city</th>
#       <th id="T_4f358_level0_col3" class="col_heading level0 col3" >attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f358_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f358_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_4f358_row0_col1" class="data row0 col1" >10293</td>
#       <td id="T_4f358_row0_col2" class="data row0 col2" >Hyderabad</td>
#       <td id="T_4f358_row0_col3" class="data row0 col3" >No</td>
#     </tr>
#     <tr>
# ...

# %%
df.head(10).style.highlight_max(subset=['salary','age'],color='lightgreen').highlight_min(subset=['salary','age'],color='lightpink')
# Out:
# <style type="text/css">
# #T_d15d7_row0_col1, #T_d15d7_row6_col0 {
#   background-color: lightpink;
# }
# #T_d15d7_row8_col0, #T_d15d7_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d15d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d15d7_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_d15d7_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_d15d7_level0_col2" class="col_heading level0 col2" >city</th>
#       <th id="T_d15d7_level0_col3" class="col_heading level0 col3" >attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d15d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d15d7_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_d15d7_row0_col1" class="data row0 col1" >10293</td>
#       <td id="T_d15d7_row0_col2" class="data row0 col2" >Hyderabad</td>
# ...

# %%
df.head(10).style.highlight_between(left=20000, right=50000, subset='salary')
# Out:
# <style type="text/css">
# #T_5f887_row2_col1, #T_5f887_row3_col1, #T_5f887_row4_col1, #T_5f887_row6_col1, #T_5f887_row7_col1, #T_5f887_row8_col1, #T_5f887_row9_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5f887">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f887_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_5f887_level0_col1" class="col_heading level0 col1" >salary</th>
#       <th id="T_5f887_level0_col2" class="col_heading level0 col2" >city</th>
#       <th id="T_5f887_level0_col3" class="col_heading level0 col3" >attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f887_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f887_row0_col0" class="data row0 col0" >44</td>
#       <td id="T_5f887_row0_col1" class="data row0 col1" >10293</td>
#       <td id="T_5f887_row0_col2" class="data row0 col2" >Hyderabad</td>
# ...

# %%
f'{round(15488,-3):,}'
# Out:
# '15,000'

# %%
pd.date_range(start='2020-01-01', end='2020-01-31', freq='d').to_list()
# Out:
# [Timestamp('2020-01-01 00:00:00', freq='D'),
#  Timestamp('2020-01-02 00:00:00', freq='D'),
#  Timestamp('2020-01-03 00:00:00', freq='D'),
#  Timestamp('2020-01-04 00:00:00', freq='D'),
#  Timestamp('2020-01-05 00:00:00', freq='D'),
#  Timestamp('2020-01-06 00:00:00', freq='D'),
#  Timestamp('2020-01-07 00:00:00', freq='D'),
#  Timestamp('2020-01-08 00:00:00', freq='D'),
#  Timestamp('2020-01-09 00:00:00', freq='D'),
#  Timestamp('2020-01-10 00:00:00', freq='D'),
#  Timestamp('2020-01-11 00:00:00', freq='D'),
#  Timestamp('2020-01-12 00:00:00', freq='D'),
#  Timestamp('2020-01-13 00:00:00', freq='D'),
#  Timestamp('2020-01-14 00:00:00', freq='D'),
#  Timestamp('2020-01-15 00:00:00', freq='D'),
#  Timestamp('2020-01-16 00:00:00', freq='D'),
#  Timestamp('2020-01-17 00:00:00', freq='D'),
#  Timestamp('2020-01-18 00:00:00', freq='D'),
#  Timestamp('2020-01-19 00:00:00', freq='D'),
#  Timestamp('2020-01-20 00:00:00', freq='D'),
#  Timestamp('2020-01-21 00:00:00', freq='D'),
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['attrition']), df['attrition'], test_size=0.2, random_state=33)

# %%
X_train
# Out:
#       age  salary       city
# 1118   24   45991      Noida
# 996    38   23797   Banglore
# 427    34   45383  Hyderabad
# 495    22   26371      Noida
# 858    41   31338  Hyderabad
# ...   ...     ...        ...
# 1225   26   40739     Mumbai
# 658    36   50138      Noida
# 578    58   45407   Banglore
# 391    25   51335  Hyderabad
# 1044   24   38680     Mumbai
#
# [1200 rows x 3 columns]

# %%
from sklearn.compose import ColumnTransformer
